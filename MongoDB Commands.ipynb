# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://snehbhandari:4umZ36RvSekIk1Xu@calendardata.erd5u.mongodb.net/?retryWrites=true&w=majority&appName=CalendarData"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
import csv
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://snehbhandari:4umZ36RvSekIk1Xu@calendardata.erd5u.mongodb.net/?retryWrites=true&w=majority&appName=CalendarData"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e) 

# Specify the collection you want to work with
collection = client['CalendarData']['events']

header = ['Event ID', 'Start Date', 'Start Time', 'End Date', 'End Time', 'Duration', 'Event Title', 'Calendar Name']

csv_event_ids = set()

with open('calendar_events.csv', 'r') as csvFile:
    reader = csv.DictReader(csvFile)
    
    for each in reader:
        event_id = each.get('Event ID')
        csv_event_ids.add(event_id)
        
        # Check if an entry with the same Event ID exists in the collection
        existing_event = collection.find_one({'Event ID': event_id})
        
        row = {field: each.get(field) for field in header}
        
        if existing_event:
            # Check if the existing document differs from the new data
            if any(existing_event.get(field) != row.get(field) for field in header):
                # Update the document with the new data
                collection.update_one({'Event ID': event_id}, {'$set': row})
                print(f"Updated: {row}")
            else:
                print(f"No update needed: Event ID {event_id}")
        else:
            # Insert the new event if it does not exist
            collection.insert_one(row)
            print(f"Inserted: {row}")

# Find and delete any events in the database that are not in the CSV
db_event_ids = set(event['Event ID'] for event in collection.find({}, {'Event ID': 1}))

events_to_delete = db_event_ids - csv_event_ids

for event_id in events_to_delete:
    collection.delete_one({'Event ID': event_id})
    print(f"Deleted: Event ID {event_id} as it is no longer in the CSV")
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
# Inserted: {'Event ID': '3lrukevq2epb45c7u5dn8ltmfv', 'Start Date': '2023-10-16', 'Start Time': '18:00:00-04:00', 'End Date': '2023-10-16', 'End Time': '21:00:00-04:00', 'Duration': '3:00:00', 'Event Title': 'Probability', 'Calendar Name': 'Classes', '_id': ObjectId('66d4bb93abe0404a18c9cf99')}
# Inserted: {'Event ID': '2s1l09loak88tt26at19drfou8', 'Start Date': '2023-10-17', 'Start Time': '18:00:00-04:00', 'End Date': '2023-10-17', 'End Time': '21:00:00-04:00', 'Duration': '3:00:00', 'Event Title': 'Regression', 'Calendar Name': 'Classes', '_id': ObjectId('66d4bb94abe0404a18c9cf9a')}
# Inserted: {'Event ID': '76rc05hd5aq2sf2fhickltpnq0', 'Start Date': '2023-10-18', 'Start Time': '17:40:00-04:00', 'End Date': '2023-10-18', 'End Time': '20:40:00-04:00', 'Duration': '3:00:00', 'Event Title': 'Data Structures', 'Calendar Name': 'Classes', '_id': ObjectId('66d4bb94abe0404a18c9cf9b')}
# ...

# %%
import csv
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://snehbhandari:4umZ36RvSekIk1Xu@calendardata.erd5u.mongodb.net/?retryWrites=true&w=majority&appName=CalendarData"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# Specify the collection you want to work with
collection = client['CalendarData']['events']

# Find all unique calendar names
unique_calendar_names = collection.distinct('Calendar Name')

# Print the unique calendar names
print("Unique Calendar Names:", unique_calendar_names)
# Out:
# Unique Calendar Names: ['Classes', 'Intermittent Fasting', 'Job Applications', 'PTL CS170', 'Projects', 'Study', 'Workout']

# %%
document = collection.find_one()

if document:
    headers = list(document.keys())
    print("Headers:", headers)
else:
    print("No documents found in the collection.")
# Out:
# Headers: ['_id', 'Event ID', 'Start Date', 'Start Time', 'End Date', 'End Time', 'Duration', 'Event Title', 'Calendar Name']

# %%
total_duration = collection.aggregate([
    {"$match": {"Calendar Name": "Classes"}},
    {"$group": {"_id": None, "totalDuration": {"$sum": "$Duration"}}}
])

# Retrieve the total duration from the aggregation result
total_duration_value = next(total_duration, {}).get("totalDuration", 0)

print(f"Total Duration of all events in the 'Study' calendar: {total_duration_value}")
# Out:
# Total Duration of all events in the 'Study' calendar: 0

# %%
collection = client['CalendarData']['events']

# Aggregate to find total duration of events in the "Study" calendar
pipeline = [
    {"$match": {"Calendar Name": "Study"}},
    {"$group": {"_id": None, "totalDuration": {"$sum": {"$toDouble": "$Duration"}}}}
]

# Execute the aggregation pipeline
result = list(collection.aggregate(pipeline))

# Check if we have any results
if result:
    total_duration_value = result[0].get("totalDuration", 0)
else:
    total_duration_value = 0

print(f"Total Duration of all events in the 'Study' calendar: {total_duration_value}")
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[11], line 10
#       4 pipeline = [
#       5     {"$match": {"Calendar Name": "Study"}},
#       6     {"$group": {"_id": None, "totalDuration": {"$sum": {"$toDouble": "$Duration"}}}}
#       7 ]
#       9 # Execute the aggregation pipeline
# ---> 10 result = list(collection.aggregate(pipeline))
#      12 # Check if we have any results
#      13 if result:
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/collection.py:2720, in Collection.aggregate(self, pipeline, session, let, comment, **kwargs)
#    2642 """Perform an aggregation using the aggregation framework on this
#    2643 collection.
#    2644
#    (...)
#    2717     https://mongodb.com/docs/manual/reference/command/aggregate
#    2718 """
#    2719 with self.__database.client._tmp_session(session, close=False) as s:
# ...

# %%
def duration_to_seconds(duration_str):
    try:
        # Parse the duration string
        duration = datetime.strptime(duration_str, "%H:%M:%S")
        # Convert to total seconds
        return duration.hour * 3600 + duration.minute * 60 + duration.second
    except ValueError:
        return 0

# Aggregate to find total duration of events in the "Study" calendar
pipeline = [
    {"$match": {"Calendar Name": "Study"}},
    {"$project": {"_id": 0, "Duration": 1}},
]

# Execute the aggregation pipeline
cursor = collection.aggregate(pipeline)

# Sum durations
total_seconds = 0
for document in cursor:
    duration_str = document.get("Duration", "00:00:00")
    total_seconds += duration_to_seconds(duration_str)

# Convert total seconds to total minutes or hours as needed
total_minutes = total_seconds / 60
total_hours = total_seconds / 3600

print(f"Total Duration of all events in the 'Study' calendar: {total_minutes:.2f} minutes ({total_hours:.2f} hours)")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 23
#      21 for document in cursor:
#      22     duration_str = document.get("Duration", "00:00:00")
# ---> 23     total_seconds += duration_to_seconds(duration_str)
#      25 # Convert total seconds to total minutes or hours as needed
#      26 total_minutes = total_seconds / 60
#
# Cell In[14], line 4, in duration_to_seconds(duration_str)
#       1 def duration_to_seconds(duration_str):
#       2     try:
#       3         # Parse the duration string
# ----> 4         duration = datetime.strptime(duration_str, "%H:%M:%S")
#       5         # Convert to total seconds
#       6         return duration.hour * 3600 + duration.minute * 60 + duration.second
#
# AttributeError: module 'datetime' has no attribute 'strptime'

# %%
import datetime
from datetime import strptime
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 2
#       1 import datetime
# ----> 2 from datetime import strptime
#
# ImportError: cannot import name 'strptime' from 'datetime' (/Users/snehbhandari/anaconda3/lib/python3.11/datetime.py)

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
from datetime import datetime

uri = "mongodb+srv://snehbhandari:4umZ36RvSekIk1Xu@calendardata.erd5u.mongodb.net/?retryWrites=true&w=majority&appName=CalendarData"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)

# Specify the collection you want to work with
collection = client['CalendarData']['events']

# Function to convert "HH:MM:SS" to total seconds
def duration_to_seconds(duration_str):
    try:
        # Parse the duration string
        duration = datetime.strptime(duration_str, "%H:%M:%S")
        # Convert to total seconds
        return duration.hour * 3600 + duration.minute * 60 + duration.second
    except ValueError:
        return 0

# Aggregate to find total duration of events in the "Study" calendar
pipeline = [
    {"$match": {"Calendar Name": "Projects"}},
    {"$project": {"_id": 0, "Duration": 1}},
]

# Execute the aggregation pipeline
cursor = collection.aggregate(pipeline)

# Sum durations
total_seconds = 0
for document in cursor:
    duration_str = document.get("Duration", "00:00:00")
    total_seconds += duration_to_seconds(duration_str)

# Convert total seconds to total minutes or hours as needed
total_minutes = total_seconds / 60
total_hours = total_seconds / 3600

print(f"Total Duration of all events in the 'Study' calendar: {total_minutes:.2f} minutes ({total_hours:.2f} hours)")
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
# Total Duration of all events in the 'Study' calendar: 2445.00 minutes (40.75 hours)

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
from datetime import datetime

uri = "mongodb+srv://snehbhandari:4umZ36RvSekIk1Xu@calendardata.erd5u.mongodb.net/?retryWrites=true&w=majority&appName=CalendarData"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)

# Specify the collection you want to work with
collection = client['CalendarData']['events']

# Function to convert "HH:MM:SS" to total seconds
def duration_to_seconds(duration_str):
    try:
        # Parse the duration string
        duration = datetime.strptime(duration_str, "%H:%M:%S")
        # Convert to total seconds
        return duration.hour * 3600 + duration.minute * 60 + duration.second
    except ValueError:
        return 0

# Aggregate to find total duration for every calendar
pipeline = [
    {"$project": {"Calendar Name": 1, "Duration": 1}},
    {"$group": {
        "_id": "$Calendar Name",
        "totalDuration": {"$sum": {"$toDouble": "$Duration"}}
    }}
]

# Execute the aggregation pipeline
cursor = collection.aggregate(pipeline)

# Print the total duration for each calendar
for document in cursor:
    calendar_name = document["_id"]
    total_duration_seconds = document["totalDuration"]
    total_minutes = total_duration_seconds / 60
    total_hours = total_duration_seconds / 3600
    print(f"Calendar: {calendar_name}")
    print(f"  Total Duration: {total_minutes:.2f} minutes ({total_hours:.2f} hours)")
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[22], line 40
#      31 pipeline = [
#      32     {"$project": {"Calendar Name": 1, "Duration": 1}},
#      33     {"$group": {
#    (...)
#      36     }}
#      37 ]
#      39 # Execute the aggregation pipeline
# ---> 40 cursor = collection.aggregate(pipeline)
#      42 # Print the total duration for each calendar
#      43 for document in cursor:
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/collection.py:2720, in Collection.aggregate(self, pipeline, session, let, comment, **kwargs)
#    2642 """Perform an aggregation using the aggregation framework on this
#    2643 collection.
#    2644
#    (...)
#    2717     https://mongodb.com/docs/manual/reference/command/aggregate
#    2718 """
# ...

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
from datetime import datetime

uri = "mongodb+srv://snehbhandari:4umZ36RvSekIk1Xu@calendardata.erd5u.mongodb.net/?retryWrites=true&w=majority&appName=CalendarData"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)

# Specify the collection you want to work with
collection = client['CalendarData']['events']

# Function to convert "HH:MM:SS" to total seconds
def duration_to_seconds(duration_str):
    try:
        # Parse the duration string assuming it is in HH:MM:SS format
        duration = datetime.strptime(duration_str, "%H:%M:%S")
        # Convert to total seconds
        return duration.hour * 3600 + duration.minute * 60 + duration.second
    except ValueError:
        # Handle cases where the format might be invalid
        print(f"Invalid duration format: {duration_str}")
        return 0

# Specify the collection you want to work with
collection = client['CalendarData']['events']

# Find all unique calendar names
unique_calendar_names = collection.distinct('Calendar Name')
# Define the calendar name dynamically
calendar_name = unique_calendar_names

# Aggregate to find total duration of events in the specified calendar
pipeline = [
    {"$match": {"Calendar Name": calendar_name}},
    {"$project": {"_id": 0, "Duration": 1}}
]

# Execute the aggregation pipeline
cursor = collection.aggregate(pipeline)

# Sum durations
total_seconds = 0
for document in cursor:
    duration_str = document.get("Duration", "00:00:00")
    total_seconds += duration_to_seconds(duration_str)

# Convert total seconds to minutes or hours as needed
total_minutes = total_seconds / 60
total_hours = total_seconds / 3600

print(f"Total Duration of all events in the '{calendar_name}' calendar: {total_minutes:.2f} minutes ({total_hours:.2f} hours)")
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
# Total Duration of all events in the '['Classes', 'Intermittent Fasting', 'Job Applications', 'PTL CS170', 'Projects', 'Study', 'Workout']' calendar: 0.00 minutes (0.00 hours)

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
from datetime import datetime

uri = "mongodb+srv://snehbhandari:4umZ36RvSekIk1Xu@calendardata.erd5u.mongodb.net/?retryWrites=true&w=majority&appName=CalendarData"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)

# Specify the collection you want to work with
collection = client['CalendarData']['events']

# Function to convert "HH:MM:SS" to total seconds
def duration_to_seconds(duration_str):
    try:
        # Parse the duration string assuming it is in HH:MM:SS format
        duration = datetime.strptime(duration_str, "%H:%M:%S")
        # Convert to total seconds
        return duration.hour * 3600 + duration.minute * 60 + duration.second
    except ValueError:
        # Handle cases where the format might be invalid
        print(f"Invalid duration format: {duration_str}")
        return 0

# Find all unique calendar names
unique_calendar_names = collection.distinct('Calendar Name')

# Process each calendar
for calendar_name in unique_calendar_names:
    # Aggregate to find total duration of events in the current calendar
    pipeline = [
        {"$match": {"Calendar Name": calendar_name}},
        {"$project": {"_id": 0, "Duration": 1}}
    ]

    # Execute the aggregation pipeline
    cursor = collection.aggregate(pipeline)

    # Sum durations
    total_seconds = 0
    for document in cursor:
        duration_str = document.get("Duration", "00:00:00")
        total_seconds += duration_to_seconds(duration_str)

    # Convert total seconds to minutes or hours as needed
    total_minutes = total_seconds / 60
    total_hours = total_seconds / 3600

    print(f"Total Duration of all events in the '{calendar_name}' calendar: {total_minutes:.2f} minutes ({total_hours:.2f} hours)")
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
# Total Duration of all events in the 'Classes' calendar: 20085.00 minutes (334.75 hours)
# Total Duration of all events in the 'Intermittent Fasting' calendar: 2760.00 minutes (46.00 hours)
# Total Duration of all events in the 'Job Applications' calendar: 2688.00 minutes (44.80 hours)
# Total Duration of all events in the 'PTL CS170' calendar: 4755.00 minutes (79.25 hours)
# Total Duration of all events in the 'Projects' calendar: 2445.00 minutes (40.75 hours)
# Total Duration of all events in the 'Study' calendar: 9349.00 minutes (155.82 hours)
# Total Duration of all events in the 'Workout' calendar: 1205.00 minutes (20.08 hours)
